# %% [markdown]
# # Examen Módulo 1 - Ecuaciones diferenciales. <font color =blue> Tipo de examen 1.  </font>
#
# Lea cuidadosamente las siguientes indicaciones antes de comenzar el examen:
#
# - Para resolver el examen edite este mismo archivo y renómbrelo de la siguiente manera: *Examen1_ApellidoNombre*, donde *ApellidoNombre* corresponde a su apellido paterno con la inicial en mayúscula, seguido de su primer nombre con la inicial en mayúscula **sin acentos**. Por ejemplo, en mi caso el nombre del archivo sería Examen1_LopezMichel.
# - Resuelva los puntos en el espacio provisto. Si requiere agregar más celdas para código o escritura, hágalo.
# - Recuerde que también se está evaluando su capacidad de interpretar los resultados. Escriba sus interpretaciones/conclusiones en celdas utilizando *Markdown*.
# - El formato de presentación de todo el examen en general debe ser adecuado. Use tamaños de letra, colores, etiquetas, etcétera.
# - No se resuelven dudas de ningún tipo por los profesores de la asignatura. Por favor, absténgase de preguntar.
# - Revise bien el tipo de examen. Sólo se le calificará si realiza el tipo de examen asignado.

# %% [markdown]
# # Las cosas del amor.
#
# Consideramos un modelo simple de la dinámica del amor/odio en una pareja, propuesto por Strogatz en 1988.
#
# - Strogatz, S.H. (1988) *Love affairs and differential equations*, Math. Magazine 61, 35.

# %% [markdown]
# ### Primer punto (50 puntos).
#
# Romeo está enamorado de Julieta, pero en este caso, Julieta tiene sentimientos volubles. Mientras Romeo más la ama, ella quiere huir de él. Pero cuando Romeo no muestra atención, Julieta lo empieza a ver muy atractivo.
#
# Del otro lado, Romeo tiene sentimientos imitativos. Esto quiere decir que se pone cariñoso cuando ella lo ama y se vuelve frío cuando ella lo odia.
#
# Sean:
#
# - $x_1(t)$ : amor/odio de Romeo hacia Julieta en el tiempo  $t$ .
# - $x_2(t)$ : amor/odio de Julieta hacia Romeo en el tiempo  $t$ .
#
# Consideraremos que un valor positivo de  $x_1$  o  $x_2$  corresponde a amor, y que un valor negativo corresponde a odio.
#
# Un modelo del romance anteriormente descrito es
# $$ \frac{dx_1}{dt}=ax_2,$$
# $$ \frac{dx_2}{dt}=−bx_1$$
#
# con  $a$  y  $b$  constantes positivas. Definimos  $x=[x_1,x_2]^T$.
#
# 1. (20 puntos) Simular este sistema eligiendo los parámetros  $a=b=1$  y condiciones iniciales  $x(0)=[x1(0),x2(0)]^T=[5,5]^T$, usando un vector de tiempo de $0$ a $50$ (unidades de tiempo).
# 2. (15 puntos)
#     - (10 puntos) Graficar las soluciones en el tiempo, es decir,  $x_1$  vs. $t$  y  $x_2$ vs  $t$.
#     - (5 puntos) ¿Qué forma tienen dichas soluciones? ¿Qué se puede decir del amor/odio de Romeo hacia Julieta? ¿Qué se puede decir del amor/odio de Julieta hacia Romeo?
# 3. (15 puntos)
#     - (10 puntos) Graficar el retrato de fase, es decir,  $x_2$  vs  $x_1$.
#     - (5 puntos) ¿Cómo es el amor de Romeo y Julieta? ¿Considera usted sano este tipo de amor?

# %%
from scipy.integrate import odeint
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

def f(y,t):
    x1 = y[0]
    x2 = y[1]
    f0 = a*x2
    f1 =  -b*x1
    return [f0,f1]
a,b=1,1
x10 = 5
x20 = 5
x0 = [x10,x20]
t = np.linspace(0,50)

soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
for i in range(0,50):
    x=[X[i],Y[i]]
    print (np.transpose(x),"^T")
# Out:
# [ 5.  5.] ^T
# [ 6.87669824 -1.64651735] ^T
# [ 2.19327542 -6.72231639] ^T
# [-4.58245246 -5.38526922] ^T
# [-6.98668684  1.08912974] ^T
# [-2.72587506  6.52453857] ^T
# [ 4.13532287  5.73577396] ^T
# [ 7.05157269 -0.52471122] ^T
# [ 3.24087755 -6.28464098] ^T
# [-3.66149727 -6.04925093] ^T
# [-7.07093654 -0.04309471] ^T
# [-3.73495846  6.00417245] ^T
# [ 3.16403478  6.32367661] ^T
# [ 7.04465342  0.61062243] ^T
# [ 4.20492808 -5.68494339] ^T
# [-2.64614642 -6.55727938] ^T
# [-6.97289314 -1.17420823] ^T
# [-4.64775243  5.32901511] ^T
# [ 2.11117579  6.74855106] ^T
# [ 6.85611882  1.73021376] ^T
# [ 5.06057282 -4.93868483] ^T
# [-1.56257638 -6.89625703] ^T
# [-6.69508432 -2.27504985] ^T
# [-5.44072448  4.51647235] ^T
# [ 1.00388942  6.99944379] ^T
# [ 6.49082928  2.80519929] ^T
# [ 5.78575314 -4.0651038 ] ^T
# [-0.43872181 -7.05744508] ^T
# [-6.24467212 -3.3172396 ] ^T
# [-6.09343157  3.58749241] ^T
# [-0.12927795  7.06988665] ^T
# [ 5.95820224  3.80786516] ^T
# ...

# %%
def f(y,t):
    x1 = y[0]
    x2 = y[1]
    f0 = a*x2
    f1 =  -b*x1
    return [f0,f1]
a,b=1,1
x10 = 5
x20 = 5
x0 = [x10,x20]
t = np.linspace(0,50,250)

soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.figure(figsize=(15,6))
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()

# %% [markdown]
# **Interpretación:** Romeo y Julieta se aman o se odian con la misma intensidad solamente cuando estan en 5 o -5. Su amor oscila con una forma senoidal, y básicamente Romeo va siguiendo el amor de Juleita de manera retrasada, pero como lo sigue, llega al punto en que Julieta cambia su amor/odio de sentido, y el ciclo se repite a través del tiempo

# %%
plt.figure(figsize=(6,6))
plt.scatter(Y,X,lw=5,s=6,cmap='winter',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()

# %% [markdown]
# **Interpretación: **
#
#  -Cuando el amor de Julieta aumenta:   amor de Romeo aumenta.
#
#  -Cuando el amor de Julieta disminuye: amor de Romeo disminuye.
#
#  -Cuando el amor de Romeo disminuye:   amor de Julieta aumenta.
#
#  -Cuando el amor de Romeo aumenta:     amor de Julieta disminuye.
#
# Es un ciclo que se repite a través del tiempo, no creo que sea sano porque hay un momento en que los dos se odian, y podrian terminar en ese momento.

# %% [markdown]
# ### Segundo punto.
# En este punto consideraremos a Romeo y a Julieta como dos amantes cautelosos idénticos.
#
# Entonces, un modelo que describe este romance es
#
# $$\frac{dx_1}{dt} = -ax_1 + bx_2$$
# $$\frac{dx_2}{dt} = bx_1 -ax_2$$
#
# con  $a$  y  $b$  constantes positivas. Definimos  $x=[x_1,x_2]^T$.
#
# Simular este sistema y obtener gráficas de  $x_1$  vs.  $t$ ,  $x_2$  vs.  $t$ y  $x_2$  vs.  $x_1$  en cada uno de los siguientes casos. Además, concluya acerca de cómo es el amor entre Romeo y Julieta cuando  $t \rightarrow \infty$.
#
#
# 1. (25 puntos) Para  $a=2$  y  $b=1$.
#
#     - $x(0)=[x_1(0),x_2(0)]^T =[2,1]^T$.
#     - $x(0)=[x_1(0),x_2(0)]^T =[−2,1]^T$.
#     - $x(0)=[x_1(0),x_2(0)]^T =[−2,−1]^T$.
#     - $x(0)=[x_1(0),x_2(0)]^T =[2,−1]^T$.
# 2. (25 puntos) Para  $a=1$  y  $b=2$.
#     - $x(0)=[x_1(0),x_2(0)]T=[2,1]^T$.
#     - $x(0)=[x_1(0),x_2(0)]T=[−2,1]^T$.
#     - $x(0)=[x_1(0),x_2(0)]T=[−2,−1]^T$.
#     - $x(0)=[x_1(0),x_2(0)]T=[2,−1]^T$.

# %%
#1
def f(y,t):
    x1 = y[0]
    x2 = y[1]
    f0 = -a*x1+b*x2
    f1 =  b*x1-a*x2
    return [f0,f1]
a,b=2,1
x10 = 2
x20 = 1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='spring',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()
#2
x10 = -2
x20 = 1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='summer',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()

#3
x10 = -2
x20 = -1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='autumn',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()

#4
x10 = 2
x20 = -1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='winter',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()

# %% [markdown]
# **Interpretación:** En los cuatro casos, su amor tiende a 0. Romeo siempre tiene sentimientos a Julieta al inicio con el doble de intensidad, independientemente de si es amor o odio. En dos de los casos los dos tienen los mismos sentimientos por el otro. En los otros dos, uno ama y el otro odia y viceversa. Sin importar esto, los sentimientos tienden a ser neutrales, no hay amor ni odio.

# %%
#1
def f(y,t):
    x1 = y[0]
    x2 = y[1]
    f0 = -a*x1+b*x2
    f1 =  b*x1-a*x2
    return [f0,f1]
a,b=1,2
x10 = 2
x20 = 1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='viridis',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()
#2
x10 = -2
x20 = 1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='plasma',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()

#3
x10 = -2
x20 = -1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='inferno',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()

#4
x10 = 2
x20 = -1
x0 = [x10,x20]
t = np.linspace(0,50,500)
soln = odeint(f,x0,t)
X = soln[:,0]
Y = soln[:,1]
plt.plot(t,X, label="Romeo a Julieta")
plt.plot(t,Y,'r', label="Julieta a Romeo")
plt.title("Amor/Odio Romeo/Julieta",fontsize = 16)
plt.xlabel("Tiempo",fontsize = 14)
plt.ylabel("Odio       /      Amor",fontsize = 14)
plt.legend(loc = 'upper right', prop={'size': 14})
plt.show()
plt.figure(figsize=(4,4))
plt.scatter(Y,X,lw=5,s=6,cmap='magma',c=Y)
plt.xlabel('amor julieta a romeo')
plt.ylabel('amor romeo a julieta')
plt.title("Retrato de fase Romeo y Julieta")
plt.grid(True)
plt.show()

# %% [markdown]
# **Interpretación:** En todos los casos, inician sn tener sentimientos uno por el otro. Su amor aumenta o disminuye exactamente de la misma manera. En dos casos aumenta exponencialmente y en los otros dos disminuye de la misma manera. Sin tomar en cuenta el modelo exponencial (de manera filosófica)  y como comentario final, si se comienzan adiando o amando sus sentimientos tienden a extinguirse, pero si comienzan por no tener sentiemientos y terminan odiándose o amándose intensamente, pareciera una asíntota la que se crea, porque evenualemente su amor los mataría, así como en la obra
