# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x_0=0
elemets=[1,-1]
probabilities = [.5,.5]
delta_x=np.random.choice(elemets,1000, p=probabilities)
y=np.ones(len(np.cumsum(delta_x)))
plt.plot(np.cumsum(delta_x))
plt.xlabel("Tiempo")
plt.ylabel("Distancia")

# %%
def walker():
    global x,y
    eleccion=random.randint(0,3)
    if eleccion == 0:
        x+=1
    elif eleccion ==1:
        x-=1
    elif eleccion==2:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
pos=np.zeros((2,1000))
for i in np.arange(0,len(pos[0]),1):
    pos[:,i] =walker()
plt.plot(pos[0,:],pos[1,:],'bo-')
plt.plot(pos[0,-1],pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    x+=random.randint(-1,1)
    y+=random.randint(-1,1)
    return [x,y]
x=0
y=0
pos=np.zeros((2,1000))
for i in np.arange(0,len(pos[0]),1):
    pos[:,i] =walker()
plt.plot(pos[0,:],pos[1,:],'bo-')
plt.plot(pos[0,-1],pos[1,-1],'ro-')

# %%
x_0=np.array([[0],[0]])
delta_x=np.random.uniform(-1,1,(2,100))
x=np.concatenate((x_0,np.cumsum(delta_x,axis=1)),axis=1)
rw=plt.plot(x[0],x[1],'ro-')

# %%
plt.hist(np.random.normal(0,1,(1000,1)));

# %%
def walker():
    global x,y
    eleccion=random.uniform(0,1)
    if eleccion <.4:
        x+=1
    elif eleccion <.6:
        x-=1
    elif eleccion<.8:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
pos=np.zeros((2,1000))
for i in np.arange(0,len(pos[0]),1):
    pos[:,i] =walker()
plt.plot(pos[0,:],pos[1,:],'bo-')
plt.plot(pos[0,-1],pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    eleccion=random.uniform(0,1)
    if eleccion <.1:
        x+=1
    elif eleccion <.2:
        x-=1
    elif eleccion<.8:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
pos=np.zeros((2,1000))
for i in np.arange(0,len(pos[0]),1):
    pos[:,i] =walker()
plt.plot(pos[0,:],pos[1,:],'bo-')
plt.plot(pos[0,-1],pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    x+=np.random.normal(0,2000)
    y+=random.gauss(0,2000)
    return [x,y]
x=0
y=0
pos=np.zeros((2,100))
for i in np.arange(0,len(pos[0]),1):
    pos[:,i] =walker()
plt.plot(pos[0,:],pos[1,:],'bo-')
plt.plot(pos[0,-1],pos[1,-1],'ro-')

# %%
def walker():
    global x,y
    r=random.uniform(0,1)
    if r<.01:
        x+=np.random.normal(0,200)
        y+=random.gauss(0,200)
    else:
        x+=np.random.normal(0,1)
        y+=random.gauss(0,1)
    return [x,y]
x=0
y=0
pos=np.zeros((2,1000))
for i in np.arange(0,len(pos[0]),1):
    pos[:,i] =walker()
plt.plot(pos[0,:],pos[1,:],'bo-')
plt.plot(pos[0,-1],pos[1,-1],'ro-')

# %%
# %%timeit
def walker():
    global x,y
    eleccion=random.uniform(0,1)
    if eleccion <.4:
        x+=1
    elif eleccion <.6:
        x-=1
    elif eleccion<.8:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
pos=np.zeros((2,1000))
for i in np.arange(0,len(pos[0]),1):
    pos[:,i] =walker()
plt.plot(pos[0,:],pos[1,:],'bo-')
plt.plot(pos[0,-1],pos[1,-1],'ro-')
# Out:
# The slowest run took 15.97 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1 loop, best of 3: 17.7 ms per loop

# %%
# %%timeit
inicio=np.array([[0],[0]])
elements=np.array([[1,-1,0,0],[0,0,1,-1]])
probabilities=[.4,.2,.2,.2]
pasos=elements[:,np.random.choice(elements.shape[1],1000,p=probabilities)]
pasos=np.concatenate((inicio,pasos),axis=1)
pos=np.cumsum(pasos,axis=1)
plt.plot(pos[0,:],pos[1,:],'bo-')
# Out:
# The slowest run took 36.29 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 3: 4.7 ms per loop
