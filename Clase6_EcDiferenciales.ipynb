# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# GRAFICAR 10E^2t

# %%
t=np.arange(0,10,.1)
f=10*np.exp(2*t)
plt.title('solución', fontsize=14)
plt.plot(t,f,'green')

# %%
t=np.arange(0,2*np.pi,.1)
f=np.sin(t)
#plt.plot(t,f)

# %% [markdown]
# 3 MANERAS DE GRAFICAR

# %%
#1
z=np.arange(0,10)
d=z**2
plt.plot(z,d)

#2
def f(x):
    return x**2
x=np.arange(0,10)
plt.plot(x,f(x))

#3
y=lambda t:t**2
t=np.arange(0,10)
plt.plot(x,f(x),'ro')

# %%
tfin=3
h=.1
f1=lambda x2:10*np.exp(2*t)
t=np.arange(0,tfin+.1,.1)
plt.plot(t,f1(t),"b")

def f2(pk,h):
    return pk+h*2*pk
pk=np.arange(0,tfin+h,h)
pk[0]=10
for k in np.arange(0,pk.size-1):
    pk[k+1]=f2(pk[k],h)
    #print (pk[k+1])
tk=np.arange(0,tfin+h,h)
plt.plot(tk,pk)
